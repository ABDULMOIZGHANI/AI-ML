# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Showing the data of Moto Repair

# %%
dataset = pd.read_csv(r"C:\Users\PMLS\Desktop\Python for AIML\data\Repair_Motor_vehicle.csv")
dataset.head(3)
# Out:
#   Registration Type                     Corporation Name  \
# 0       Corporation  MG Auto & Truck Repair Services LLC
# 1       Corporation          E & S Towing Services, Inc.
# 2       Corporation               Mohamed M. Kheiry, LLC
#
#                             Trade Name      Business Address  \
# 0  MG Auto & Truck Repair Services LLC  8146 Beechcraft Ave.
# 1                 E & S Towing Service    15814 Paramount Dr
# 2                     Satellite Motors       8109 Mayor Lane
#
#   Business Address2           City State    Zip    Phone Number  \
# 0              8146   Gaithersburg    MD  20879  (301) 848-1294
# 1               NaN      Rockville    MD  20855  (240) 304-9367
# 2               NaN  Silver Spring    MD  20910  (301) 585-7876
#
#    # ASE Certified Mechanics Tow Storage Address  Tow Storage 2  \
# 0                          0                  NaN           NaN
# 1                          0   15814 Paramount Dr           NaN
# ...

# %%
# display the no. of columns and rows
dataset.shape
# Out:
# (2432, 20)

# %%
dataset.isnull() #--> it shows the true and false values
# Out:
#       Registration Type  Corporation Name  Trade Name  Business Address  \
# 0                 False             False       False             False
# 1                 False             False       False             False
# 2                 False             False       False             False
# 3                 False             False       False             False
# 4                 False             False       False             False
# ...                 ...               ...         ...               ...
# 2427              False             False       False             False
# 2428              False             False       False             False
# 2429              False             False       False             False
# 2430              False             False       False             False
# 2431              False             False       False             False
#
#       Business Address2   City  State    Zip  Phone Number  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Registration Type               0
# Corporation Name              614
# Trade Name                      4
# Business Address               79
# Business Address2            2316
# City                           43
# State                          43
# Zip                          1131
# Phone Number                   55
# # ASE Certified Mechanics       0
# Tow Storage Address          2184
# Tow Storage 2                2420
# Tow Storage City             2224
# Tow Storage State            2225
# Tow Storage Zip              2227
# Tow Storage Phone            2254
# Issue Date                      0
# Expiration                      0
# Registration No.                0
# Location                       43
# dtype: int64

# %% [markdown]
# ### Percenntage null value
#
# callculate the null values in the form of percent

# %%
(dataset.isnull().sum() / dataset.shape[0]) * 100
# Out:
# Registration Type             0.000000
# Corporation Name             25.246711
# Trade Name                    0.164474
# Business Address              3.248355
# Business Address2            95.230263
# City                          1.768092
# State                         1.768092
# Zip                          46.504934
# Phone Number                  2.261513
# # ASE Certified Mechanics     0.000000
# Tow Storage Address          89.802632
# Tow Storage 2                99.506579
# Tow Storage City             91.447368
# Tow Storage State            91.488487
# Tow Storage Zip              91.570724
# Tow Storage Phone            92.680921
# Issue Date                    0.000000
# Expiration                    0.000000
# Registration No.              0.000000
# Location                      1.768092
# dtype: float64

# %%
#find total null values 
dataset.isnull().sum().sum()
# Out:
# np.int64(17862)

# %% [markdown]
# ### Find the percentage of total null values in dataset

# %%
(dataset.isnull().sum().sum() / (dataset.shape[0] * dataset.shape[1])) * 100
# Out:
# np.float64(36.72286184210527)

# %%
(dataset.notnull().sum().sum() / (dataset.shape[0] * dataset.shape[1])) * 100
# Out:
# np.float64(63.27713815789474)

# %% [markdown]
# ## Drawing a graph according to our null or not null dataset

# %%
sns.heatmap(dataset.isnull())
plt.show
# white area shows the null value in the graph
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
